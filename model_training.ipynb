# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv('ajaib.co.id_reviews.csv')
df.head()
# Out:
#                                reviewId         userName  \
# 0  1e9f1226-b2ce-4101-9cea-bd57262c0230  Pengguna Google
# 1  08ad0973-0c57-48b4-909c-dc63717e18a9  Pengguna Google
# 2  063fab80-9b48-4be5-b747-658544cb8909  Pengguna Google
# 3  06009f20-f077-4d95-80e5-40d2c9fa96fe  Pengguna Google
# 4  17bb8845-258f-472e-abe2-d278f4ba8275  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Jelek sekali, pelayanan CS nya lama, kita mau ...      1              0
# 1  apk nya sangat bagus dan sangat mudah untuk di...      5              0
# 2  Saya pemula yg satu bulan belakangan coba trad...      5              0
# 3  Pertama kali pake ajaib sangat gampang buat na...      5              0
# 4  aseet saya hilang di portofolio.. ada apa ini....      2              0
#
#   reviewCreatedVersion                   at  \
# 0               2.65.1  2025-07-16 11:28:49
# 1               2.71.0  2025-07-16 11:26:56
# 2               2.71.0  2025-07-16 10:52:55
# 3                  NaN  2025-07-16 10:52:12
# 4               2.73.0  2025-07-16 10:36:53
#
#                                         replyContent            repliedAt  \
# 0  Hi Kak , mohon maaf atas ketidaknyamanannya da...  2025-07-16 14:53:20
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4  Hi kak. Mohon maaf atas ketidaknyamanannya, te...  2025-07-16 14:53:52
#
#   appVersion
# 0     2.65.1
# 1     2.71.0
# 2     2.71.0
# 3        NaN
# 4     2.73.0

# %%
def label_sentiment(score):
    if score > 3:
        return 'positive'
    elif score == 3:
        return 'neutral'
    else:
        return 'negative'

df['sentiment'] = df['score'].apply(label_sentiment)
df.head()
# Out:
#                                reviewId         userName  \
# 0  1e9f1226-b2ce-4101-9cea-bd57262c0230  Pengguna Google
# 1  08ad0973-0c57-48b4-909c-dc63717e18a9  Pengguna Google
# 2  063fab80-9b48-4be5-b747-658544cb8909  Pengguna Google
# 3  06009f20-f077-4d95-80e5-40d2c9fa96fe  Pengguna Google
# 4  17bb8845-258f-472e-abe2-d278f4ba8275  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Jelek sekali, pelayanan CS nya lama, kita mau ...      1              0
# 1  apk nya sangat bagus dan sangat mudah untuk di...      5              0
# 2  Saya pemula yg satu bulan belakangan coba trad...      5              0
# 3  Pertama kali pake ajaib sangat gampang buat na...      5              0
# 4  aseet saya hilang di portofolio.. ada apa ini....      2              0
#
#   reviewCreatedVersion                   at  \
# 0               2.65.1  2025-07-16 11:28:49
# 1               2.71.0  2025-07-16 11:26:56
# 2               2.71.0  2025-07-16 10:52:55
# 3                  NaN  2025-07-16 10:52:12
# 4               2.73.0  2025-07-16 10:36:53
#
#                                         replyContent            repliedAt  \
# 0  Hi Kak , mohon maaf atas ketidaknyamanannya da...  2025-07-16 14:53:20
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4  Hi kak. Mohon maaf atas ketidaknyamanannya, te...  2025-07-16 14:53:52
#
#   appVersion sentiment
# 0     2.65.1  negative
# 1     2.71.0  positive
# 2     2.71.0  positive
# 3        NaN  positive
# 4     2.73.0  negative

# %%
reviews = df['content'].values
labels = pd.get_dummies(df['sentiment']).values

X_train, X_test, y_train, y_test = train_test_split(reviews, labels, test_size=0.2, random_state=42)

# %%
tokenizer = Tokenizer(num_words=5000, oov_token='<unk>')
tokenizer.fit_on_texts(X_train)

X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)

X_train_padded = pad_sequences(X_train_sequences, maxlen=120, padding='post', truncating='post')
X_test_padded = pad_sequences(X_test_sequences, maxlen=120, padding='post', truncating='post')

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=5000, output_dim=64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.GlobalMaxPool1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# %%
history = model.fit(X_train_padded, y_train, epochs=20, validation_data=(X_test_padded, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 256s 136ms/step - accuracy: 0.7912 - loss: 0.5804 - val_accuracy: 0.8730 - val_loss: 0.3688
# Epoch 2/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 246s 134ms/step - accuracy: 0.8784 - loss: 0.3705 - val_accuracy: 0.8850 - val_loss: 0.3372
# Epoch 3/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 261s 133ms/step - accuracy: 0.8873 - loss: 0.3379 - val_accuracy: 0.8899 - val_loss: 0.3259
# Epoch 4/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 257s 131ms/step - accuracy: 0.8948 - loss: 0.3193 - val_accuracy: 0.8933 - val_loss: 0.3213
# Epoch 5/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 245s 134ms/step - accuracy: 0.8976 - loss: 0.3142 - val_accuracy: 0.8951 - val_loss: 0.3137
# Epoch 6/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 264s 135ms/step - accuracy: 0.9000 - loss: 0.2979 - val_accuracy: 0.8935 - val_loss: 0.3102
# Epoch 7/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 247s 135ms/step - accuracy: 0.9020 - loss: 0.2938 - val_accuracy: 0.8963 - val_loss: 0.3066
# Epoch 8/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 259s 133ms/step - accuracy: 0.9033 - loss: 0.2831 - val_accuracy: 0.8965 - val_loss: 0.3058
# Epoch 9/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 246s 135ms/step - accuracy: 0.9038 - loss: 0.2779 - val_accuracy: 0.8966 - val_loss: 0.3085
# Epoch 10/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 264s 136ms/step - accuracy: 0.9056 - loss: 0.2709 - val_accuracy: 0.8978 - val_loss: 0.3089
# Epoch 11/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 260s 135ms/step - accuracy: 0.9065 - loss: 0.2708 - val_accuracy: 0.8972 - val_loss: 0.3142
# Epoch 12/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 262s 135ms/step - accuracy: 0.9086 - loss: 0.2639 - val_accuracy: 0.8981 - val_loss: 0.3149
# Epoch 13/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 239s 131ms/step - accuracy: 0.9084 - loss: 0.2614 - val_accuracy: 0.8978 - val_loss: 0.3170
# Epoch 14/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 246s 135ms/step - accuracy: 0.9108 - loss: 0.2543 - val_accuracy: 0.8942 - val_loss: 0.3263
# Epoch 15/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 261s 134ms/step - accuracy: 0.9126 - loss: 0.2504 - val_accuracy: 0.8967 - val_loss: 0.3195
# Epoch 16/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 247s 135ms/step - accuracy: 0.9145 - loss: 0.2494 - val_accuracy: 0.8912 - val_loss: 0.3248
# Epoch 17/20
# 1830/1830 ━━━━━━━━━━━━━━━━━━━━ 261s 134ms/step - accuracy: 0.9160 - loss: 0.2431 - val_accuracy: 0.8950 - val_loss: 0.3284

# %%
loss, accuracy = model.evaluate(X_test_padded, y_test)
print(f'Test Accuracy: {accuracy * 100:.2f}%')
# Out:
# 458/458 ━━━━━━━━━━━━━━━━━━━━ 16s 34ms/step - accuracy: 0.8978 - loss: 0.3118
# Test Accuracy: 89.81%
